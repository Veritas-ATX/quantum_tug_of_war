# %% [markdown]
# # Qubit Tug-of-War Bot Testing Notebook

# %%
# %run GamePlayer.py
# REPLACE below with your test file (or comment out if developing in notebook)
# %run austin_basic_bot.py
# %run greedy_bot.py

# %%
# This is the entire Random Bot code for reference and testing
class RandomBot(GameBot):
    def play_action(self,
                    team: int,
                    round_number: int,
                    hand: List[GameAction],
                    prev_turn: List) -> Optional[GameAction]:
        
        #this is the probability that it chooses to play an action
        p = 0.2
        
        #if the hand is non-empty and we flip a coin and it lands heads with probability p,
        #choose a random action
        if len(hand) > 0 and np.random.random() < p:
            action = random.choice(hand)
            return action
        
        #otherwise, don't play an action
        return None

# %%
# The basic set-up for the MyStrategy Class
# Uncomment if you want to develop class in this notebook
# '''
# Insert high-level explanation of your strategy here. Why did you design this strategy?
# When should it work well, and when should it have trouble?
# '''
# class MyStrategy(GameBot):

#     '''
#         Initialize your bot here. The init function must take in a bot_name.
#         You can use this to initialize any variables or data structures
#         to keep track of things in the game
#     '''
#     def __init__(self,bot_name):
#         self.bot_name = bot_name        #do not remove this
    
#     def play_action(self,
#                     team: int,
#                     round_number: int,
#                     hand: List[GameAction],
#                     prev_turn: List) -> Optional[GameAction]:
        

#         ##### IMPLEMENT AWESOME STRATEGY HERE ##################
        
        
#         #######################################################
#         return None

# %%
# Run a single game pitting some MyStrategy class vs Random Bot
# Prints the winning state and a log of the game
stratbot = MyStrategy("MyStrat")
randombot = RandomBot("The Randos")
greedybot = GreedyBot("greedy")
# stratbot as team |0> and randombot as team |1>
gp = GamePlayer(randombot, stratbot)
winning_state = gp.play_rounds()
print(winning_state)
log = gp.get_event_log()
print(log)
# Out:
# [0 1]
# Team |0> is The Randos
# Team |1> is MyStrat
# ======================================
# 	 Team |0> added Z to their hand (1/20)
# 	 Team |1> added M to their hand (1/20)
# 	 Team |0> added H to their hand (2/20)
# 	 Team |1> added Z to their hand (2/20)
# 	 Team |0> added X to their hand (3/20)
# 	 Team |1> added R to their hand (3/20)
# 	 Team |0> added X to their hand (4/20)
# 	 Team |1> added X to their hand (4/20)
# 	 Team |0> added R to their hand (5/20)
# 	 Team |1> added R to their hand (5/20)
# ======================================
# Round 0. State: [0.707,0.707]
# 	 Team |1> plays M
# 	 State collapsed to [0, 1]
# Round 1. State: [-0.031,1.000]
# Round 2. State: [-0.063,0.998]
# Round 3. State: [-0.094,0.996]
# Round 4. State: [-0.125,0.992]
# Round 5. State: [-0.156,0.988]
# Round 6. State: [-0.187,0.982]
# Round 7. State: [-0.218,0.976]
# Round 8. State: [-0.249,0.969]
# Round 9. State: [-0.279,0.960]
# Round 10. State: [-0.309,0.951]
# Round 11. State: [-0.339,0.941]
# Round 12. State: [-0.368,0.930]
# Round 13. State: [-0.397,0.918]
# Round 14. State: [-0.426,0.905]
# Round 15. State: [-0.454,0.891]
# 	 Team |1> added R to their hand (6/20)
# Round 16. State: [-0.482,0.876]
# 	 Team |1> plays Z
# Round 17. State: [-0.454,-0.891]
# 	 Team |1> added R to their hand (7/20)
# Round 18. State: [-0.426,-0.905]
# 	 Team |0> plays X
# 	 Team |1> plays X
# Round 19. State: [-0.397,-0.918]
# Round 20. State: [-0.368,-0.930]
# Round 21. State: [-0.339,-0.941]
# 	 Team |0> added R to their hand (6/20)
# Round 22. State: [-0.309,-0.951]
# Round 23. State: [-0.279,-0.960]
# Round 24. State: [-0.249,-0.969]
# Round 25. State: [-0.218,-0.976]
# 	 Team |0> plays Z
# 	 Team |0> added M to their hand (7/20)
# Round 26. State: [-0.249,0.969]
# 	 Team |1> added Z to their hand (8/20)
# Round 27. State: [-0.279,0.960]
# 	 Team |1> plays R
# Round 28. State: [-0.249,0.969]
# Round 29. State: [-0.218,0.976]
# 	 Team |0> plays R
# Round 30. State: [-0.249,0.969]
# 	 Team |0> added X to their hand (8/20)
# Round 31. State: [-0.279,0.960]
# Round 32. State: [-0.309,0.951]
# 	 Team |1> added R to their hand (9/20)
# Round 33. State: [-0.339,0.941]
# 	 Team |0> plays X
# 	 Team |1> plays R
# Round 34. State: [0.930,-0.368]
# 	 Team |1> added H to their hand (10/20)
# Round 35. State: [0.918,-0.397]
# 	 Team |1> plays H
# Round 36. State: [0.397,0.918]
# Round 37. State: [0.426,0.905]
# Round 38. State: [0.454,0.891]
# Round 39. State: [0.482,0.876]
# Round 40. State: [0.509,0.861]
# 	 Team |0> added R to their hand (9/20)
# 	 Team |1> added Z to their hand (11/20)
# Round 41. State: [0.536,0.844]
# 	 Team |1> plays R
# Round 42. State: [0.509,0.861]
# Round 43. State: [0.482,0.876]
# Round 44. State: [0.454,0.891]
# Round 45. State: [0.426,0.905]
# 	 Team |0> plays H
# Round 46. State: [0.951,-0.309]
# Round 47. State: [0.960,-0.279]
# Round 48. State: [0.969,-0.249]
# Round 49. State: [0.976,-0.218]
# 	 Team |1> added R to their hand (12/20)
# Round 50. State: [0.982,-0.187]
# 	 Team |1> plays R
# Round 51. State: [0.976,-0.218]
# 	 Team |0> plays M
# 	 State collapsed to [1, 0]
# 	 Team |1> added Z to their hand (13/20)
# Round 52. State: [1.000,-0.031]
# Round 53. State: [0.998,-0.063]
# Round 54. State: [0.996,-0.094]
# 	 Team |0> added R to their hand (10/20)
# Round 55. State: [0.992,-0.125]
# Round 56. State: [0.988,-0.156]
# 	 Team |0> plays X
# Round 57. State: [-0.125,0.992]
# Round 58. State: [-0.094,0.996]
# 	 Team |0> added H to their hand (11/20)
# Round 59. State: [-0.063,0.998]
# 	 Team |0> added X to their hand (12/20)
# Round 60. State: [-0.031,1.000]
# Round 61. State: [-0.000,1.000]
# 	 Team |0> plays R
# 	 Team |1> plays Z
# 	 Team |0> added H to their hand (13/20)
# Round 62. State: [0.031,-1.000]
# Round 63. State: [0.063,-0.998]
# Round 64. State: [0.094,-0.996]
# Round 65. State: [0.125,-0.992]
# 	 Team |0> plays H
# 	 Team |1> added R to their hand (14/20)
# Round 66. State: [-0.637,0.771]
# 	 Team |1> plays R
# Round 67. State: [-0.613,0.790]
# Round 68. State: [-0.588,0.809]
# 	 Team |0> added Z to their hand (14/20)
# Round 69. State: [-0.562,0.827]
# Round 70. State: [-0.536,0.844]
# Round 71. State: [-0.509,0.861]
# Round 72. State: [-0.482,0.876]
# Round 73. State: [-0.454,0.891]
# Round 74. State: [-0.426,0.905]
# Round 75. State: [-0.397,0.918]
# 	 Team |1> added Z to their hand (15/20)
# Round 76. State: [-0.368,0.930]
# Round 77. State: [-0.339,0.941]
# Round 78. State: [-0.309,0.951]
# Round 79. State: [-0.279,0.960]
# Round 80. State: [-0.249,0.969]
# Round 81. State: [-0.218,0.976]
# Round 82. State: [-0.187,0.982]
# Round 83. State: [-0.156,0.988]
# Round 84. State: [-0.125,0.992]
# Round 85. State: [-0.094,0.996]
# 	 Team |0> plays H
# 	 Team |0> added Z to their hand (15/20)
# Round 86. State: [0.613,-0.790]
# Round 87. State: [0.588,-0.809]
# Round 88. State: [0.562,-0.827]
# Round 89. State: [0.536,-0.844]
# 	 Team |0> plays Z
# 	 Team |1> plays Z
# Round 90. State: [0.509,-0.861]
# Round 91. State: [0.482,-0.876]
# Round 92. State: [0.454,-0.891]
# Round 93. State: [0.426,-0.905]
# 	 Team |0> plays R
# Round 94. State: [0.454,-0.891]
# Round 95. State: [0.482,-0.876]
# 	 Team |0> added R to their hand (16/20)
# 	 Team |1> added Z to their hand (16/20)
# Round 96. State: [0.509,-0.861]
# 	 Team |1> plays R
# Round 97. State: [0.482,-0.876]
# Round 98. State: [0.454,-0.891]
# Round 99. State: [0.426,-0.905]
# --------Entering Overtime for 7 extra rounds, and Team |1> goes last--------
# Round 100. State: [0.397,-0.918]
# 	 Team |0> plays X
# Round 101. State: [-0.905,0.426]
# Round 102. State: [-0.891,0.454]
# Round 103. State: [-0.876,0.482]
# Round 104. State: [-0.861,0.509]
# Round 105. State: [-0.844,0.536]
# Round 106. State: [-0.827,0.562]
# 	 State collapsed to [0, 1]
#
# Team |1>, MyStrat, wins!

# %%
gp.log
# Out:
# 'Team |0> is greedy\nTeam |1> is MyStrat\n======================================\n\t Team |0> added Z to their hand (1/20)\n\t Team |1> added X to their hand (1/20)\n\t Team |0> added Z to their hand (2/20)\n\t Team |1> added R to their hand (2/20)\n\t Team |0> added Z to their hand (3/20)\n\t Team |1> added X to their hand (3/20)\n\t Team |0> added H to their hand (4/20)\n\t Team |1> added X to their hand (4/20)\n\t Team |0> added H to their hand (5/20)\n\t Team |1> added Z to their hand (5/20)\n======================================\nRound 0. State: [0.707,0.707]\n\t Team |0> plays Z\n\t Team |1> plays R\nRound 1. State: [0.685,-0.729]\n\t Team |0> added X to their hand (6/20)\nRound 2. State: [0.661,-0.750]\n\t Team |0> plays H\nRound 3. State: [-0.031,1.000]\n\t Team |0> added R to their hand (7/20)\nRound 4. State: [0.000,1.000]\n\t Team |0> plays R\n\t Team |1> added X to their hand (6/20)\nRound 5. State: [-0.031,1.000]\n\t Team |1> plays Z\n\t Team |0> added H to their hand (8/20)\n\t Team |1> added X to their hand (7/20)\nRound 6. State: [0.000,-1.000]\n\t Team |0> plays H\n\t Team |1> plays X\nRound 7. State: [0.729,-0.685]\n\t Team |1> added H to their hand (8/20)\nRound 8. State: [0.750,-0.661]\n\t Team |1> plays H\nRound 9. State: [0.031,1.000]\n\t Team |0> added Z to their hand (9/20)\nRound 10. State: [0.000,1.000]\n\t Team |0> plays Z\nRound 11. State: [0.031,-1.000]\n\t Team |1> added X to their hand (9/20)\nRound 12. State: [0.063,-0.998]\nRound 13. State: [0.094,-0.996]\nRound 14. State: [0.125,-0.992]\nRound 15. State: [0.156,-0.988]\nRound 16. State: [0.187,-0.982]\nRound 17. State: [0.218,-0.976]\nRound 18. State: [0.249,-0.969]\n\t Team |0> added H to their hand (10/20)\nRound 19. State: [0.279,-0.960]\n\t Team |0> plays Z\n\t Team |0> added Z to their hand (11/20)\nRound 20. State: [0.249,0.969]\n\t Team |0> plays H\n\t Team |1> plays X\nRound 21. State: [-0.536,0.844]\n\t Team |1> added R to their hand (10/20)\nRound 22. State: [-0.562,0.827]\n\t Team |1> plays R\n\t Team |0> added H to their hand (12/20)\n\t Team |1> added H to their hand (11/20)\nRound 23. State: [-0.536,0.844]\n\t Team |0> plays Z\nRound 24. State: [-0.562,-0.827]\nRound 25. State: [-0.588,-0.809]\nRound 26. State: [-0.613,-0.790]\nRound 27. State: [-0.637,-0.771]\nRound 28. State: [-0.661,-0.750]\n\t Team |0> added R to their hand (13/20)\nRound 29. State: [-0.685,-0.729]\n\t Team |0> plays R\nRound 30. State: [-0.661,-0.750]\nRound 31. State: [-0.637,-0.771]\n\t Team |0> added X to their hand (14/20)\nRound 32. State: [-0.613,-0.790]\n\t Team |0> plays H\n\t Team |1> plays X\nRound 33. State: [0.156,-0.988]\n\t Team |0> added H to their hand (15/20)\n\t Team |1> added H to their hand (12/20)\nRound 34. State: [0.187,-0.982]\n\t Team |0> plays H\n\t Team |1> plays H\n\t Team |1> added X to their hand (13/20)\nRound 35. State: [0.218,-0.976]\nRound 36. State: [0.249,-0.969]\nRound 37. State: [0.279,-0.960]\nRound 38. State: [0.309,-0.951]\n\t Team |0> added H to their hand (16/20)\nRound 39. State: [0.339,-0.941]\n\t Team |0> plays H\n\t Team |1> plays H\n\t Team |1> added R to their hand (14/20)\nRound 40. State: [0.368,-0.930]\n\t Team |1> plays R\n\t Team |0> added X to their hand (17/20)\nRound 41. State: [0.339,-0.941]\n\t Team |0> plays X\n\t Team |1> added H to their hand (15/20)\nRound 42. State: [-0.930,0.368]\n\t Team |1> plays X\nRound 43. State: [0.339,-0.941]\n\t Team |0> added R to their hand (18/20)\n\t Team |1> added R to their hand (16/20)\nRound 44. State: [0.309,-0.951]\n\t Team |0> plays R\n\t Team |1> plays R\n\t Team |1> added H to their hand (17/20)\nRound 45. State: [0.279,-0.960]\nRound 46. State: [0.249,-0.969]\nRound 47. State: [0.218,-0.976]\nRound 48. State: [0.187,-0.982]\nRound 49. State: [0.156,-0.988]\nRound 50. State: [0.125,-0.992]\nRound 51. State: [0.094,-0.996]\nRound 52. State: [0.063,-0.998]\nRound 53. State: [0.031,-1.000]\nRound 54. State: [0.000,-1.000]\nRound 55. State: [-0.031,-1.000]\nRo ...

# %%
# Test MyStrategy class vs Random Bot 10,000 times for each team value
win_counter = 0
num_matches = 100
for i in range(num_matches):
    stratbot = MyStrategy("MyStrat")
    randombot = RandomBot("The Randos")
    greedybot = GreedyBot("greedy")
    gp = GamePlayer(stratbot, greedybot)
    winning_state = gp.play_rounds()
    if winning_state[0] == 1:
        win_counter += 1
print(f'Team 1 winning as team 0: {win_counter/num_matches}%')
print(f'Team 2 winning as team 1: {(num_matches-win_counter)/num_matches}%')

win_counter = 0
for i in range(num_matches):
    stratbot = MyStrategy("MyStrat")
    randombot = RandomBot("The Randos")
    greedybot = GreedyBot("greedy")
    gp = GamePlayer(greedybot, stratbot)
    winning_state = gp.play_rounds()
    if winning_state[0] == 0:
        win_counter += 1
print(f'Team 1 winning as team 1: {win_counter/num_matches}%')
print(f'Team 2 winning as team 0: {(num_matches-win_counter)/num_matches}%')
# Out:
# Team 1 winning as team 0: 0.0%
# Team 2 winning as team 1: 1.0%
# Team 1 winning as team 1: 0.92%
# Team 2 winning as team 0: 0.08%

# %% [markdown]
# Every team must work independently on their bot (teams should not share code). Your bots will be graded in the following way. Points will be awarded based on a combination of:
# 1. Effort and creativity,
# 2. Whether your code includes in the beginning a discussion about your strategy and your rationale behind the design choices, and
# 3. Performance against other bots.
#
# As a target, you should try to design a bot that consistently beats `RandomBot` at least 60% of the time.

# %%
'''
Looks only at current round maxing and assumes opponent has no impact.
Does NOT take into account rotation
Treats measurement as if it is equivalent to passing
Coded w/out taking into account turn order correctly if team 1
vs. Random Bot 10000 games:
Percent win as team 0: 62.14%
Percent win as team 1: 56.17%
'''
class MyStrategy_V1(GameBot):
    '''
        Initialize your bot here. The init function must take in a bot_name.
        You can use this to initialize any variables or data structures
        to keep track of things in the game
    '''
    def __init__(self, bot_name):
        self.bot_name = bot_name        #do not remove this
        self.state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.direction = 1
        self.theta = float(2*np.pi/100.0)
        self.test_state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.round = 0
        self.dealt_count = 0
        self.hand_size = 0
    
    def rotation(self):
        thet = float(self.theta * self.direction)
        rotate = np.array([[np.cos(thet / 2), -np.sin(thet / 2)], 
                           [np.sin(thet / 2), np.cos(thet / 2)]])
        self.state = np.dot(rotate, self.state)
    
    def update_state(self, action):
        if action == GameAction.PAULIX:
            X = np.array([[0, 1], [1, 0]])
            self.state = np.dot(X, self.state)
        elif action == GameAction.PAULIZ:
            Z = np.array([[1, 0], [0, -1]])
            self.state = np.dot(Z, self.state)
        elif action == GameAction.HADAMARD:
            H = np.array([[np.sqrt(1/2), np.sqrt(1/2)], [np.sqrt(1/2), -np.sqrt(1/2)]])
            self.state = np.dot(H, self.state)
        elif action == GameAction.REVERSE:
            self.direction = -1 * self.direction
    
    def update_with_prev(self, prev_turn):
        # Update state model based on previous turn and rotations
        prev_actions = [prev_turn['team0_action'], prev_turn['team1_action']]
        prev_measures = [prev_turn['team0_measurement'], prev_turn['team1_measurement']]
        for i in range(2):
            if prev_actions[i] is not None:
                if prev_actions[i] == GameAction.MEASURE:
                    self.state = prev_measures[i]
                else:
                    self.update_state(prev_actions[i])
        self.rotation()
            
    def try_action(self, action, goal):
        # Update test state, keep as is if measure state
        if action == GameAction.PAULIX:
            X = np.array([[0, 1], [1, 0]])
            self.test_state = np.dot(X, self.test_state)
        elif action == GameAction.PAULIZ:
            Z = np.array([[1, 0], [0, -1]])
            self.test_state = np.dot(Z, self.test_state)
        elif action == GameAction.HADAMARD:
            H = np.array([[np.sqrt(1/2), np.sqrt(1/2)], [np.sqrt(1/2), -np.sqrt(1/2)]])
            self.test_state = np.dot(H, self.test_state)
        # Get the 0 state probability p if team 0, 1-p for team 1
        probability = self.test_state[0]**2
        if probability < 0:
            probability = 0
        elif probability > 1:
            probability = 1
        if goal == 1:
            probability = 1 - probability
        return probability

    def play_action(self,
                    team: int,
                    round_number: int,
                    hand: List[GameAction],
                    prev_turn: List) -> Optional[GameAction]:
        ##### IMPLEMENT AWESOME STRATEGY HERE ##################
        # Update qubit state based on prev round
        if self.round != 0:
            self.update_with_prev(prev_turn)
        # Increment round counter
        self.round += 1
        # Check if we were dealt cards and update counters
        if len(hand) > self.hand_size:
            self.dealt_count += len(hand) - self.hand_size
            self.hand_size = len(hand)
        # If not near end of game or at hand limit, hoard cards
        if self.hand_size < 5 and self.round <= 98:
            return None
        # Use reverse action first
        if GameAction.REVERSE in hand:
            self.hand_size -= 1
            return GameAction.REVERSE
        # Test out actions in hand for which maximizes win prob
        # CURRENTLY DOES NOT TAKE INTO ACCOUNT ROTATIONS
        best_prob = 0
        best_action = None
        for action in hand:
            self.test_state = np.copy(self.state)
            temp_prob = self.try_action(action, team)
            if temp_prob > best_prob:
                best_prob = temp_prob
                best_action = action
        # Check if passing is optimal compared to hand
        self.test_state = np.copy(self.state)
        temp_prob = self.try_action(None, team)
        if temp_prob >= best_prob:
            return None
        self.hand_size -= 1
        return best_action
    #######################################################

# %%
'''
Looks only at current round maxing and assumes opponent has no impact.
Takes into account rotation
Treats measurement as if it is equivalent to passing
Coded w/out taking into account turn order correctly if team 1
vs. Random Bot 10000 games:
Percent win as team 0: 80.14%
Percent win as team 1: 66.6%
'''
class MyStrategy_V2(GameBot):
    '''
        Initialize your bot here. The init function must take in a bot_name.
        You can use this to initialize any variables or data structures
        to keep track of things in the game
    '''
    def __init__(self, bot_name):
        self.bot_name = bot_name        #do not remove this
        self.state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.direction = 1
        self.theta = float(2*np.pi/100.0)
        self.test_state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.test_direction = 1
        self.round = 0
        self.dealt_count = 0
        self.hand_size = 0

    def update_state(self, action):
        if action == GameAction.PAULIX:
            X = np.array([[0, 1], [1, 0]])
            self.state = np.dot(X, self.state)
        elif action == GameAction.PAULIZ:
            Z = np.array([[1, 0], [0, -1]])
            self.state = np.dot(Z, self.state)
        elif action == GameAction.HADAMARD:
            H = np.array([[np.sqrt(1/2), np.sqrt(1/2)], [np.sqrt(1/2), -np.sqrt(1/2)]])
            self.state = np.dot(H, self.state)
        elif action == GameAction.REVERSE:
            self.direction = -1 * self.direction
    
    def update_with_prev(self, prev_turn):
        # Update state model based on previous turn and rotations
        prev_actions = [prev_turn['team0_action'], prev_turn['team1_action']]
        prev_measures = [prev_turn['team0_measurement'], prev_turn['team1_measurement']]
        for i in range(2):
            if prev_actions[i] is not None:
                if prev_actions[i] == GameAction.MEASURE:
                    self.state = prev_measures[i]
                else:
                    self.update_state(prev_actions[i])
        thet = float(self.theta * self.direction)
        rotate = np.array([[np.cos(thet / 2), -np.sin(thet / 2)], 
                           [np.sin(thet / 2), np.cos(thet / 2)]])
        self.state = np.dot(rotate, self.state)
            
    def try_action(self, action, goal):
        # Update test state/direction depending on action tried
        # If a measurement, pretends equivalent to passing
        if action == GameAction.PAULIX:
            X = np.array([[0, 1], [1, 0]])
            self.test_state = np.dot(X, self.test_state)
        elif action == GameAction.PAULIZ:
            Z = np.array([[1, 0], [0, -1]])
            self.test_state = np.dot(Z, self.test_state)
        elif action == GameAction.HADAMARD:
            H = np.array([[np.sqrt(1/2), np.sqrt(1/2)], [np.sqrt(1/2), -np.sqrt(1/2)]])
            self.test_state = np.dot(H, self.test_state)
        elif action == GameAction.REVERSE:
            self.test_direction = -1 * self.test_direction
        # Rotate test qubit (this assumes your opponent does nothing)
        thet = float(self.theta * self.test_direction)
        rotate = np.array([[np.cos(thet / 2), -np.sin(thet / 2)], 
                           [np.sin(thet / 2), np.cos(thet / 2)]])
        self.test_state = np.dot(rotate, self.test_state)
        # Get the 0 state probability p if team 0, 1-p for team 1
        probability = self.test_state[0]**2
        if probability < 0:
            probability = 0
        elif probability > 1:
            probability = 1
        if goal == 1:
            probability = 1 - probability
        return probability

    def play_action(self,
                    team: int,
                    round_number: int,
                    hand: List[GameAction],
                    prev_turn: List) -> Optional[GameAction]:
        ##### IMPLEMENT AWESOME STRATEGY HERE ##################
        # Update qubit state based on prev round
        if self.round != 0:
            self.update_with_prev(prev_turn)
        # Increment round counter
        self.round += 1
        # Check if we were dealt cards and update counters
        if len(hand) > self.hand_size:
            self.dealt_count += len(hand) - self.hand_size
            self.hand_size = len(hand)
        # If not near end of game or at hand limit, hoard cards
        if self.hand_size < 5 and self.round <= 98:
            return None
        # Test out actions in hand for max win prob (and passing)
        # Treats game as if ending and only plans one step ahead
        # Compares to what qubit looks like after rotation!
        best_prob = 0
        best_action = None
        for i in range(len(hand)+1):
            if i == len(hand):
                action = None
            else:
                action = hand[i]
            self.test_state = np.copy(self.state)
            temp_prob = self.try_action(action, team)
            if temp_prob > best_prob:
                best_prob = temp_prob
                best_action = action
        if best_action is not None:
            self.hand_size -= 1
        return best_action
    #######################################################

# %%
'''
Looks only at current round maxing and assumes opponent has no impact.
Takes into account rotation
Treats measurement as if it is equivalent to passing
Correctly updates state even if playing as team 1
vs. Random Bot 10000 games:
Percent win as team 0: 85.69%
Percent win as team 1: 85.67%
'''
class MyStrategy_V3(GameBot):
    '''
        Initialize your bot here. The init function must take in a bot_name.
        You can use this to initialize any variables or data structures
        to keep track of things in the game
    '''
    def __init__(self, bot_name):
        self.bot_name = bot_name        #do not remove this
        self.state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.direction = 1
        self.theta = float(2*np.pi/100.0)
        self.test_state = np.array([np.sqrt(0.5), np.sqrt(0.5)])
        self.test_direction = 1
        self.round = 0
        self.dealt_count = 0
        self.hand_size = 0
        
    def rotate(self, state, direction):
        theta = float(self.theta * direction)
        rotate = np.array([[np.cos(theta / 2), -np.sin(theta / 2)], 
                           [np.sin(theta / 2), np.cos(theta / 2)]])
        state = np.dot(rotate, state)
        return state

    def update_state(self, action, state, direction):
        if action == GameAction.PAULIX:
            X = np.array([[0, 1], [1, 0]])
            state = np.dot(X, state)
        elif action == GameAction.PAULIZ:
            Z = np.array([[1, 0], [0, -1]])
            state = np.dot(Z, state)
        elif action == GameAction.HADAMARD:
            H = np.array([[np.sqrt(1/2), np.sqrt(1/2)], [np.sqrt(1/2), -np.sqrt(1/2)]])
            state = np.dot(H, state)
        elif action == GameAction.REVERSE:
            direction *= -1
        return state, direction
            
    def update_team(self, prev_turn, team):
        prev_action = prev_turn[f'team{team}_action']
        prev_measurement = prev_turn[f'team{team}_measurement']
        if prev_action is not None:
            if prev_action == GameAction.MEASURE:
                self.state = prev_measurement
            else:
                self.state, self.direction = self.update_state(prev_action, self.state, self.direction)
        
    def update_with_prev(self, prev_turn, team):
        # Update state array based on previous turn
        if team == 0:
            self.update_team(prev_turn, 0)
            self.update_team(prev_turn, 1)
            self.state = self.rotate(self.state, self.direction)
        else:
            self.update_team(prev_turn, 1)
            self.state = self.rotate(self.state, self.direction)
            self.update_team(prev_turn, 0)
            
    def try_action(self, action, team):
        # Update test state/direction depending on action tried
        # If a measurement, pretends equivalent to passing
        self.test_state, self.test_direction = self.update_state(action, self.test_state, self.test_direction)
        # Rotate test qubit (this assumes your opponent does nothing if you are team 0)
        self.test_state = self.rotate(self.test_state, self.test_direction)
        # Get the 0 state probability p if team 0, 1-p for team 1
        probability = self.test_state[0]**2
        if probability < 0:
            probability = 0
        elif probability > 1:
            probability = 1
        if team == 1:
            probability = 1 - probability
        return probability

    def play_action(self,
                    team: int,
                    round_number: int,
                    hand: List[GameAction],
                    prev_turn: List) -> Optional[GameAction]:
        ##### IMPLEMENT AWESOME STRATEGY HERE ##################
        # Update qubit state based on prev round
        if self.round == 0 and team == 1:
            self.update_team(prev_turn, 0)
        elif self.round > 0:
            self.update_with_prev(prev_turn, team)
        # Increment round counter
        self.round += 1
        # Check if we were dealt cards and update counters
        if len(hand) > self.hand_size:
            self.dealt_count += len(hand) - self.hand_size
            self.hand_size = len(hand)
        # If not near end of game or at hand limit, hoard cards
        if self.hand_size < 5 and self.round <= 98:
            return None
        # Test out actions in hand for max win prob (and passing)
        # Treats game as if ending and only plans one step ahead
        # Compares to what qubit looks like after rotation!
        best_prob = 0
        best_action = None
        for i in range(len(hand)+1):
            if i == len(hand):
                action = None
            else:
                action = hand[i]
            self.test_state = np.copy(self.state)
            self.test_direction = self.direction
            temp_prob = self.try_action(action, team)
            if temp_prob > best_prob:
                best_prob = temp_prob
                best_action = action
        if best_action is not None:
            self.hand_size -= 1
        return best_action
    #######################################################
